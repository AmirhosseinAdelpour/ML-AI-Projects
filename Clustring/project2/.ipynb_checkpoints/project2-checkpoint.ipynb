# %% [markdown]
# # Preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Credit Card Customer Data.csv")
data
# Out:
#      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 0        1         87073            100000                   2
# 1        2         38414             50000                   3
# 2        3         17341             50000                   7
# 3        4         40496             30000                   5
# 4        5         47437            100000                   6
# ..     ...           ...               ...                 ...
# 655    656         51108             99000                  10
# 656    657         60732             84000                  10
# 657    658         53834            145000                   8
# 658    659         80655            172000                  10
# 659    660         80150            167000                   9
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 0                    1                    1                 0
# 1                    0                   10                 9
# ...

# %% [markdown]
# <b>The credit limit is :</b>
#     A credit limit is the maximum amount of money a lender will allow you to spend on a credit card or a line of credit.<br>
# <b>The credit limit depends on :</b> credit score, payment history, income, credit utilization and large expenses.

# %% [markdown]
# ## Data cleaning & Feature engineering

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sl_No                660 non-null    int64
#  1   Customer Key         660 non-null    int64
#  2   Avg_Credit_Limit     660 non-null    int64
#  3   Total_Credit_Cards   660 non-null    int64
#  4   Total_visits_bank    660 non-null    int64
#  5   Total_visits_online  660 non-null    int64
#  6   Total_calls_made     660 non-null    int64
# dtypes: int64(7)
# memory usage: 36.2 KB

# %%
data.describe()
# Out:
#             Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# count  660.000000    660.000000        660.000000          660.000000
# mean   330.500000  55141.443939      34574.242424            4.706061
# std    190.669872  25627.772200      37625.487804            2.167835
# min      1.000000  11265.000000       3000.000000            1.000000
# 25%    165.750000  33825.250000      10000.000000            3.000000
# 50%    330.500000  53874.500000      18000.000000            5.000000
# 75%    495.250000  77202.500000      48000.000000            6.000000
# max    660.000000  99843.000000     200000.000000           10.000000
#
#        Total_visits_bank  Total_visits_online  Total_calls_made
# count         660.000000           660.000000        660.000000
# mean            2.403030             2.606061          3.583333
# std             1.631813             2.935724          2.865317
# min             0.000000             0.000000          0.000000
# ...

# %%
data["Total_visits"] = data["Total_visits_online"] + data["Total_visits_bank"]
data.drop(["Total_visits_bank", "Total_visits_online", "Sl_No", "Customer Key"], axis=1, inplace=True)

# %% [markdown]
# <div class="alert alert-block alert-info"><b>merging</b> the two visits columns because we are just trying to identify the loyal customers and not trying to target the customers for advertising goals.<div>

# %%
data["Credit_Limit"] = data["Avg_Credit_Limit"] * data["Total_Credit_Cards"]
data.drop(["Avg_Credit_Limit", "Total_Credit_Cards"], axis=1, inplace=True)

# %%
data
# Out:
#      Total_calls_made  Total_visits  Credit_Limit
# 0                   0             2        200000
# 1                   9            10        150000
# 2                   4             4        350000
# 3                   4             2        150000
# 4                   3            12        600000
# ..                ...           ...           ...
# 655                 0            11        990000
# 656                 2            14        840000
# 657                 1            10       1160000
# 658                 0            16       1720000
# 659                 2            12       1503000
#
# [660 rows x 3 columns]

# %% [markdown]
# ## Feature scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
scaled_data = sc.fit_transform(data)

# %%
data
# Out:
#      Total_calls_made  Total_visits  Credit_Limit
# 0                   0             2        200000
# 1                   9            10        150000
# 2                   4             4        350000
# 3                   4             2        150000
# 4                   3            12        600000
# ..                ...           ...           ...
# 655                 0            11        990000
# 656                 2            14        840000
# 657                 1            10       1160000
# 658                 0            16       1720000
# 659                 2            12       1503000
#
# [660 rows x 3 columns]

# %% [markdown]
# # Processing

# %% [markdown]
# ## Training K-MEANS model

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ### Elbow method to find the optimal number of clusters

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=3, init="k-means++", random_state=42)
y_kmeans = kmeans.fit_predict(scaled_data)

# %%
kmeans_data = data
kmeans_data["Label"] = kmeans.labels_

# %%
kmeans_data[data["Label"] == 0].describe()
# Out:
#        Total_calls_made  Total_visits   Credit_Limit  Label
# count        191.000000    191.000000     191.000000  191.0
# mean           7.392670      4.539267   29675.392670    0.0
# std            1.650438      1.464412   20742.008524    0.0
# min            5.000000      1.000000    5000.000000    0.0
# 25%            6.000000      4.000000   13500.000000    0.0
# 50%            7.000000      5.000000   26000.000000    0.0
# 75%            9.000000      5.500000   40000.000000    0.0
# max           10.000000     10.000000  150000.000000    0.0

# %%
kmeans_data[data["Label"] == 1].describe()
# Out:
#        Total_calls_made  Total_visits  Credit_Limit  Label
# count         49.000000     49.000000  4.900000e+01   49.0
# mean           1.081633     11.591837  1.239837e+06    1.0
# std            0.885925      2.813053  3.359781e+05    0.0
# min            0.000000      7.000000  5.000000e+05    1.0
# 25%            0.000000      9.000000  9.840000e+05    1.0
# 50%            1.000000     12.000000  1.240000e+06    1.0
# 75%            2.000000     13.000000  1.460000e+06    1.0
# max            3.000000     16.000000  2.000000e+06    1.0

# %%
kmeans_data[data["Label"] == 2].describe()
# Out:
#        Total_calls_made  Total_visits   Credit_Limit  Label
# count        420.000000    420.000000     420.000000  420.0
# mean           2.142857      4.454762  175464.285714    2.0
# std            1.470009      1.439422  134409.665384    0.0
# min            0.000000      1.000000    5000.000000    2.0
# 25%            1.000000      3.000000   59000.000000    2.0
# 50%            2.000000      4.000000  138000.000000    2.0
# 75%            4.000000      5.000000  267000.000000    2.0
# max            4.000000      7.000000  728000.000000    2.0

# %% [markdown]
# ## Training the HIERARCHICAL model

# %%
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# ### Using the dendrogram to find the optimal number of clusters

# %%
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(scaled_data, method = 'ward'))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.show()

# %%
hc = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage = 'ward')
y_hc = hc.fit_predict(scaled_data)

# %%
hc_data = data
hc_data["Label"] = hc.labels_

# %%
hc_data[hc_data["Label"] == 0].describe()
# Out:
#        Total_calls_made  Total_visits   Credit_Limit  Label
# count        486.000000    486.000000     486.000000  486.0
# mean           2.633745      4.438272  154316.872428    0.0
# std            1.849384      1.399299  132221.114411    0.0
# min            0.000000      1.000000    5000.000000    0.0
# 25%            1.000000      3.000000   42500.000000    0.0
# 50%            3.000000      4.000000  101000.000000    0.0
# 75%            4.000000      5.000000  252000.000000    0.0
# max            7.000000      7.000000  525000.000000    0.0

# %%
hc_data[hc_data["Label"] == 1].describe()
# Out:
#        Total_calls_made  Total_visits  Credit_Limit  Label
# count         50.000000     50.000000  5.000000e+01   50.0
# mean           1.080000     11.500000  1.229600e+06    1.0
# std            0.876915      2.858928  3.403192e+05    0.0
# min            0.000000      7.000000  5.000000e+05    1.0
# 25%            0.000000      9.000000  9.735000e+05    1.0
# 50%            1.000000     11.500000  1.232000e+06    1.0
# 75%            2.000000     13.000000  1.455000e+06    1.0
# max            3.000000     16.000000  2.000000e+06    1.0

# %%
hc_data[hc_data["Label"] == 2].describe()
# Out:
#        Total_calls_made  Total_visits   Credit_Limit  Label
# count        124.000000    124.000000     124.000000  124.0
# mean           8.314516      4.629032   29330.645161    2.0
# std            1.232137      1.605214   22329.652084    0.0
# min            6.000000      1.000000    5000.000000    2.0
# 25%            7.000000      3.000000   13000.000000    2.0
# 50%            8.000000      5.000000   24000.000000    2.0
# 75%            9.000000      6.000000   40000.000000    2.0
# max           10.000000     10.000000  150000.000000    2.0

# %% [markdown]
# ## Training DBSCAN model

# %%
from sklearn.cluster import DBSCAN

# %%
ds = DBSCAN()
y_ds = ds.fit_predict(scaled_data)

# %%
ds_data = data
ds_data["Label"] = ds.labels_

# %%
hc_data[hc_data["Label"] == 0].describe()
# Out:
#        Total_calls_made  Total_visits   Credit_Limit  Label
# count        609.000000    609.000000     609.000000  609.0
# mean           3.779967      4.467980  128875.205255    0.0
# std            2.869565      1.427886  128779.483821    0.0
# min            0.000000      1.000000    5000.000000    0.0
# 25%            1.000000      3.000000   32000.000000    0.0
# 50%            3.000000      5.000000   68000.000000    0.0
# 75%            6.000000      5.000000  210000.000000    0.0
# max           10.000000      7.000000  525000.000000    0.0

# %%
hc_data[hc_data["Label"] == -1].describe()
# Out:
#        Total_calls_made  Total_visits  Credit_Limit  Label
# count         44.000000     44.000000  4.400000e+01   44.0
# mean           1.318182     11.977273  1.200977e+06   -1.0
# std            1.474949      2.723615  3.970275e+05    0.0
# min            0.000000      7.000000  1.500000e+05   -1.0
# 25%            0.000000     10.000000  9.345000e+05   -1.0
# 50%            1.000000     12.000000  1.169500e+06   -1.0
# 75%            2.000000     14.250000  1.496250e+06   -1.0
# max            9.000000     16.000000  2.000000e+06   -1.0
