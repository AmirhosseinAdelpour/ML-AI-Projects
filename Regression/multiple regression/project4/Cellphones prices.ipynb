# %% [markdown]
# # Cellphones prices prediction

# %% [markdown]
# ## Preprocessing

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv("Cellphone.csv")
ds.head(10)
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
# 5         947   2137    12   150.0          5.5  401         4      2.30
# 6         774   1238    13   134.1          4.0  233         2      1.20
# 7         947   2137    13   150.0          5.5  401         4      2.30
# 8          99   1315    14   118.5          4.0  233         2      1.30
# 9        1103   2580    15   145.0          5.1  432         4      2.50
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# ...

# %% [markdown]
# ### Data cleaning

# %%
ds.info()
#dtypes are ok
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_id    161 non-null    int64
#  1   Price         161 non-null    int64
#  2   Sale          161 non-null    int64
#  3   weight        161 non-null    float64
#  4   resoloution   161 non-null    float64
#  5   ppi           161 non-null    int64
#  6   cpu core      161 non-null    int64
#  7   cpu freq      161 non-null    float64
#  8   internal mem  161 non-null    float64
#  9   ram           161 non-null    float64
#  10  RearCam       161 non-null    float64
#  11  Front_Cam     161 non-null    float64
#  12  battery       161 non-null    int64
#  13  thickness     161 non-null    float64
# dtypes: float64(8), int64(6)
# memory usage: 17.7 KB

# %%
ds.describe()
# Out:
#         Product_id        Price         Sale      weight  resoloution  \
# count   161.000000   161.000000   161.000000  161.000000   161.000000
# mean    675.559006  2215.596273   621.465839  170.426087     5.209938
# std     410.851583   768.187171  1546.618517   92.888612     1.509953
# min      10.000000   614.000000    10.000000   66.000000     1.400000
# 25%     237.000000  1734.000000    37.000000  134.100000     4.800000
# 50%     774.000000  2258.000000   106.000000  153.000000     5.150000
# 75%    1026.000000  2744.000000   382.000000  170.000000     5.500000
# max    1339.000000  4361.000000  9807.000000  753.000000    12.200000
#
#               ppi    cpu core    cpu freq  internal mem         ram  \
# count  161.000000  161.000000  161.000000    161.000000  161.000000
# mean   335.055901    4.857143    1.502832     24.501714    2.204994
# std    134.826659    2.444016    0.599783     28.804773    1.609831
# ...

# %% [markdown]
# <div class="alert alert-info alert-block"><h5><span style="color:red">Note: </span>these six columns [cpu core, cpu freq, internal mem, ram, RearCam, Front_Cam] have <span style="color:red">zero</span> values that should be removed.</h5></div>

# %%
ds.drop(ds[ds["cpu core"] == 0].index, inplace=True)
ds.drop(ds[ds["cpu freq"] == 0].index, inplace=True)
ds.drop(ds[ds["internal mem"] == 0].index, inplace=True)
ds.drop(ds[ds["ram"] == 0].index, inplace=True)
ds.drop(ds[ds["RearCam"] == 0].index, inplace=True)
ds.drop(ds[ds["Front_Cam"] == 0].index, inplace=True)

# %%
ds.isnull().sum()
#no null row
# Out:
# Product_id      0
# Price           0
# Sale            0
# weight          0
# resoloution     0
# ppi             0
# cpu core        0
# cpu freq        0
# internal mem    0
# ram             0
# RearCam         0
# Front_Cam       0
# battery         0
# thickness       0
# dtype: int64

# %%
ds.describe()
# Out:
#         Product_id        Price         Sale      weight  resoloution  \
# count   119.000000   119.000000   119.000000  119.000000   119.000000
# mean    694.445378  2533.974790   740.210084  182.341176     5.624202
# std     413.726650   586.705647  1760.497993  100.837669     1.260456
# min      10.000000  1390.000000    10.000000   97.000000     4.000000
# 25%     290.000000  2070.500000    36.500000  146.500000     5.000000
# 50%     776.000000  2491.000000   106.000000  158.000000     5.460000
# 75%    1071.000000  2880.000000   396.000000  174.000000     5.650000
# max    1327.000000  4361.000000  9807.000000  753.000000    12.200000
#
#               ppi    cpu core    cpu freq  internal mem         ram  \
# count  119.000000  119.000000  119.000000    119.000000  119.000000
# mean   384.857143    5.714286    1.718824     31.932773    2.785916
# std    120.195271    1.970730    0.447809     30.136337    1.464774
# ...

# %% [markdown]
# ### Splitting Data

# %%
x = ds.drop(["Price", "Product_id"], axis=1).values
y = ds["Price"].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# ## Processing

# %%
ds.corr()
# Out:
#               Product_id     Price      Sale    weight  resoloution       ppi  \
# Product_id      1.000000  0.254029  0.227721  0.100878     0.109178  0.255458
# Price           0.254029  1.000000  0.329463 -0.077704    -0.064578  0.692643
# Sale            0.227721  0.329463  1.000000  0.005488     0.004766  0.227025
# weight          0.100878 -0.077704  0.005488  1.000000     0.972156 -0.277379
# resoloution     0.109178 -0.064578  0.004766  0.972156     1.000000 -0.265987
# ppi             0.255458  0.692643  0.227025 -0.277379    -0.265987  1.000000
# cpu core       -0.033872  0.378794  0.034009  0.041724     0.096423  0.162898
# cpu freq        0.199547  0.432511  0.106901  0.008056     0.042569  0.562471
# internal mem    0.296339  0.784257  0.497748 -0.000233    -0.019483  0.495523
# ram             0.314288  0.858838  0.400433 -0.001494    -0.000605  0.589821
# RearCam         0.244486  0.462858  0.316135 -0.312850    -0.265054  0.607505
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
regr = LinearRegression()
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Evaluating model

# %%
from sklearn.metrics import r2_score

# %%
y_pred = regr.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# 0.9148602490661863
